# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image

# %%
fn = os.listdir("./img_28_size/")[450]
image_pil = Image.open(f"./img_28_size/{fn}")

plt.imshow(image_pil)

# %%
fn = os.listdir("./img_448_size/")[500]
image_pil = Image.open(f"./img_448_size/{fn}")
print(np.array(image_pil).shape)

plt.imshow(image_pil)
# Out:
# (448, 448, 3)

# %%
fn = os.listdir("./img_448_size/")[500]
image_pil = Image.open(f"./img_448_size/{fn}")

plt.imshow(np.array(image_pil))

# %%
fn = os.listdir("./Img_Selection/")[450]
image_pil = Image.open(f"./Img_Selection/{fn}")

image_pil = image_pil.resize((75, 75))

plt.imshow(image_pil)

# %%
fn = os.listdir("./Img_Selection/")[800]
image_pil = Image.open(f"./Img_Selection/{fn}")

image_pil = image_pil.resize((112, 112))

plt.imshow(image_pil)
